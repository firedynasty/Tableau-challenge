# %%
import pandas as pd

# %%
file1 = 'jul_and_aug_2017_only.csv'
# C needs the title
# C needs the tile to read
df2 = pd.read_csv(file1)

# %%
df2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
file1 = 'jul_and_aug_2017_only.csv'
# C needs the title
# C needs the tile to read
df1 = pd.read_csv(file1)

# %%
df.loc[df['channel'].isin(['sale','fullprice'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-123459617c32> in <module>
# ----> 1 df.loc[df['channel'].isin(['sale','fullprice'])]
#
# NameError: name 'df' is not defined

# %%
df1.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
df1['name'] = df1['start station id']

# %%
df1['type'] = "start"

# %%
df1['latitude'] = df1['start station latitude']
df1['longitude'] = df1['start station longitude']

# %%
print(len(df1))
print(len(df2))
# Out:
# 3552097
# 3552097

# %%
df1 = df1.loc[df1['start station id'].isin([3068, 281, 3042, 426, 514, 2006, 387, 519])]
df2 = df2.loc[df2['end station id'].isin([519,426,514,497,459,402,435,3255])]

# %%
print(len(df1))
print(len(df2))
# Out:
# 145627
# 196563

# %%
df1.head()
# Out:
#      tripduration            starttime             stoptime  start station id  \
# 79           2010  2017-07-01 00:07:54  2017-07-01 00:41:24               426
# 131           962  2017-07-01 00:12:28  2017-07-01 00:28:30               387
# 138          1543  2017-07-01 00:13:34  2017-07-01 00:39:17              2006
# 252          1008  2017-07-01 00:22:36  2017-07-01 00:39:24              3068
# 289           347  2017-07-01 00:26:38  2017-07-01 00:32:25               519
#
#           start station name  start station latitude  start station longitude  \
# 79     West St & Chambers St               40.717548               -74.013221
# 131  Centre St & Chambers St               40.712733               -74.004607
# 138   Central Park S & 6 Ave               40.765909               -73.976342
# 252   Humboldt St & Varet St               40.703172               -73.940636
# 289    Pershing Square North               40.751873               -73.977706
#
# ...

# %%
df2['name'] = df2['end station id']

# %%
df2['type'] = "end"

# %%
df2['latitude'] = df2['end station latitude']
df2['longitude'] = df2['end station longitude']

# %%
column_keys = df1.columns

# %%
initialize_df = df1.values.tolist()

# %%
list_df = df2.values.tolist()

# %%
initialize_df = initialize_df + list_df

# %%
compiled_df = pd.DataFrame(initialize_df, columns=column_keys)

# %%
compiled_df
# Out:
#         tripduration            starttime             stoptime  \
# 0               2010  2017-07-01 00:07:54  2017-07-01 00:41:24
# 1                962  2017-07-01 00:12:28  2017-07-01 00:28:30
# 2               1543  2017-07-01 00:13:34  2017-07-01 00:39:17
# 3               1008  2017-07-01 00:22:36  2017-07-01 00:39:24
# 4                347  2017-07-01 00:26:38  2017-07-01 00:32:25
# ...              ...                  ...                  ...
# 342185            84  2017-08-31 23:50:47  2017-08-31 23:52:12
# 342186           612  2017-08-31 23:50:54  2017-09-01 00:01:06
# 342187           553  2017-08-31 23:52:31  2017-09-01 00:01:44
# 342188           358  2017-08-31 23:52:55  2017-08-31 23:58:53
# 342189            70  2017-08-31 23:55:54  2017-08-31 23:57:05
#
#         start station id             start station name  \
# 0                    426          West St & Chambers St
# 1                    387        Centre St & Chambers St
# ...

# %%
compiled_df.groupby('name').count()
# Out:
#       tripduration  starttime  stoptime  start station id  start station name  \
# name
# 281          20336      20336     20336             20336               20336
# 387          18605      18605     18605             18605               18605
# 402          22185      22185     22185             22185               22185
# 426          58309      58309     58309             58309               58309
# 435          21933      21933     21933             21933               21933
# 459          22618      22618     22618             22618               22618
# 497          24333      24333     24333             24333               24333
# 514          49270      49270     49270             49270               49270
# 519          61938      61938     61938             61938               61938
# 2006         18831      18831     18831             18831               18831
# 3042          1928       1928      1928              1928                1928
# ...

# %%
compiled_df.to_csv('top_8_stations_to_from_jul_aug_2017_third.csv', index=False)

# %%
compiled_df.loc[compiled_df['name'] == 72]
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender, name, type, latitude, longitude]
# Index: []
